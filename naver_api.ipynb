# %% [markdown]
# ## 네이버 검색  API 서비스

# %% [markdown]
# #### 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "JUnq6kTGUQcUCI9yIk9x"
client_secret = "emaAVv8Iwr"

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

#encText = urllib.parse.quote("검색할 단어")
encText = urllib.parse.quote(input("검색 질의:"))

for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/news?query=" + encText + f'&display={str(display)}'+f'&start={str(start_index)}' # json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,"",items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,"",items[item_index]['description'])
            web_df.loc[idx] = [title,link,description]
            idx += 1
            
        #print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의:딥러닝
#                                                  Title  \
# 0                 래아가 윤종신 손잡자…로지도 '볼빨간사춘기 프로듀서'와 음원 낸다
# 1        [애널리스트의 시각]'52주 신저가' 크래프톤, '사실상 매도' 중립 리포트 속출
# 2           인텔리빅스, 비전 AI 기술 적용한 산업안전 솔루션으로 중대재해처벌법 넘는다
# 3                          잠잠하던 크래프톤, 연이은 신사업 확장... 왜?
# 4         [더벨]'상장 2년차' 뷰노, 곳간지기 퇴사…&quot;충원 계획 無&quot;
# ..                                                 ...
# 995                건설연, 에너지 취약계층을 위한 노후 건축물 데이터 플랫폼 개발
# 996    [파워인터뷰 화제人] 김종현 위세아이텍 대표 “1,000억 매출 고지를 달성해서...
# 997     네이버, 글로벌 AI·검색 석학 영입…&quot;우수인력으로 기술 고도화&quot;
# 998  &quot;쿠팡은 틀리지 않았는데…&quot; 손정의 찜한 '이 회사'도 성공할까 ...
# 999                      네이버, 김윤형·이장선 교수 ‘네이버 스칼라’로 영입
#
#                                                   Link  \
# 0    https://news.naver.com/main/read.naver?mode=LS...
# 1    http://www.newsway.co.kr/news/view?tp=1&ud=202...
# 2    http://www.boannews.com/media/view.asp?idx=104...
# 3    http://www.sisaweek.com/news/articleView.html?...
# 4    http://www.thebell.co.kr/front/free/contents/n...
# ..                                                 ...
# 995  http://www.boannews.com/media/view.asp?idx=104...
# 996  https://news.mtn.co.kr/news-detail/?v=20220125...
# 997  https://news.naver.com/main/read.naver?mode=LS...
# 998  https://news.naver.com/main/read.naver?mode=LS...
# 999  https://news.naver.com/main/read.naver?mode=LS...
#
#                                            Description
# 0    LG전자가 인공지능(AI) 기술과 딥러닝을 바탕으로 선보인 래아도 데뷔를 앞두고 있...
# 1    김동희 메리츠증권 연구원은 &quot;4분기 실적은 일회성 비용으로 예상치를 하회했...
# 2    또, 산업 현장에 최적화된 맞춤 영상을 딥러닝 분석을 활용해 학습하기 때문에 정확성...
# 3    지난해에 기업공개(IPO) 당시 장병규 크래프톤 의장은 메타버스라는 용어 자체에 대...
# 4    자체 개발한 AI 딥러닝 기술을 통해 X-Ray와 같은 2차원 이미지뿐 아니라 CT...
# ..                                                 ...
# 995  딥러닝 분석을 통해 최소한의 설문조사와 사진만으로도 창문의 노후 상태를 AI가 판별...
# 996  딥엑스알랩은 아바타의 생성과 특히 비주얼이펙트를 딥러닝으로 시뮬레이션하는 기술을 갖...
# 997  지난 2014년 딥러닝 기술의 일환인 컨볼루션 신경망(CNN) 기술을 자연어처리(N...
# 998  독자적인 딥러닝 알고리즘을 기반으로 초과 수익을 창출할 수 있도록 포트폴리오를 구성...
# 999  2014년 딥러닝 기술의 하나인 컨볼루션 신경망(CNN) 기술을 자연어처리(NLP)...
#
# [1000 rows x 3 columns]

# %%
web_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        1000 non-null   object
#  1   Link         1000 non-null   object
#  2   Description  1000 non-null   object
# dtypes: object(3)
# memory usage: 31.2+ KB

# %%
# 뉴스, 책, 쇼핑, 영화, 지식in 중에서 2개 이상을 선택하여 관심 주제에 대한 데이터를 1000개까지 출력(개인과제)

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "JUnq6kTGUQcUCI9yIk9x"
client_secret = "emaAVv8Iwr"

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

#encText = urllib.parse.quote("검색할 단어")
encText = urllib.parse.quote(input("검색 질의:"))

for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/book?query=" + encText + f'&display={str(display)}'+f'&start={str(start_index)}' # json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,"",items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,"",items[item_index]['description'])
            web_df.loc[idx] = [title,link,description]
            idx += 1
            
        #print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의:인공지능
#                                                  Title  \
# 0                 이것이 인공지능이다 (하룻밤에 읽는 AI(인공지능)의 모든 것!)
# 1         뉴스를 전합니다 빅데이터와 인공지능 (인문학으로 바라본 생활 속 4차 산업혁명)
# 2      인공지능은 무엇이 되려 하는가 (AI의 가능성과 위험을 바라보는 석학 25인의 시선)
# 3    인공지능과 4차 산업혁명의 미래 (십 대가 알아야 할,인간의 삶,사회 그리고 컴퓨터...
# 4                                    비전공자의 인공지능(AI) 입문
# ..                                                 ...
# 995         언리얼 엔진 4 AI 프로그래밍 에센셜 (블루프린트로 인공지능 게임 만들기)
# 996        확률적 프로그래밍 기초 원리 (머신 러닝과 인공지능을 이해하는 또 다른 방법)
# 997        사물지능 혁명 (명사의 시대에서 동사의 시대로,STEPI 미래연구 시리즈 2)
# 998           미래는 더 나아질 것인가 (인공지능, 4차 산업혁명 그리고 인간의 미래)
# 999                     지능정보사회의 공공정보화 패러다임 변화와 미래정책 연구
#
#                                                   Link  \
# 0    http://book.naver.com/bookdb/book_detail.php?b...
# 1    http://book.naver.com/bookdb/book_detail.php?b...
# 2    http://book.naver.com/bookdb/book_detail.php?b...
# 3    http://book.naver.com/bookdb/book_detail.php?b...
# 4    http://book.naver.com/bookdb/book_detail.php?b...
# ..                                                 ...
# 995  http://book.naver.com/bookdb/book_detail.php?b...
# 996  http://book.naver.com/bookdb/book_detail.php?b...
# 997  http://book.naver.com/bookdb/book_detail.php?b...
# 998  http://book.naver.com/bookdb/book_detail.php?b...
# 999  http://book.naver.com/bookdb/book_detail.php?b...
#
#                                            Description
# 0    4차 산업혁명 시대, 인공지능의 파도가 오고 있다!\nAI의 역사부터 기초 지식, ...
# 1    개인의 데이터가 사고파는 대상이 된 지 오래이며, 인공지능 봇의 시대는 이미 시작되...
# 2    인공지능의 최전선, 그리고 장기 전망\n우리 시대 최고의 과학사상가 총출동\n\n이...
# 3    또한 미래에는 인공지능 로봇이 인간의 일자리를 잠식하게 될지 모른다는 우려도 상당하...
# 4    이 책은 인공지능(AI)에 입문하려는 비전공자의 길안내서이다. 난이도는 인문사회계열...
# ..                                                 ...
# 995  acorn+PACKT 시리즈. 이 책은 정식으로 프로그래밍 교육을 받지 않은 아티스...
# 996  『확률적 프로그래밍 기초 원리』는 향후 인공지능 개발과 머신 러닝 분야의 한 축을 ...
# 997  ‘사물지능’이 이끄는 시대는 구체적으로 어떤 모습일까?\n‘디지털 이노베이션’ 개념...
# 998  인공지능, 4차 산업혁명 그리고 인간의 미래&#x0D;“알파고 이후 우리는&#x0D...
# 999  이러한 지능정보사회는 기계와 기계, 기계와 인간 등 모든 사물과 객체를 연결함으로써...
#
# [1000 rows x 3 columns]

# %% [markdown]
# #### 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 2.0 2
# | 습도 = 74
# | 기압 = 1023
# | 풍속 = 0.5

# %% [markdown]
# + 도시 = Seoul
# | 날씨 = clear sky
# | 최저 기온 = -4.0 2
# | 최고 기온 = -0.0 2
# | 습도 = 70
# | 기압 = 1024
# | 풍속 = 2.06
#
# + 도시 = Tokyo
# | 날씨 = mist
# | 최저 기온 = -0.0 2
# | 최고 기온 = 3.0 2
# | 습도 = 95
# | 기압 = 1016
# | 풍속 = 9.26
#
# + 도시 = New York
# | 날씨 = few clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 4.0 2
# | 습도 = 86
# | 기압 = 1011
# | 풍속 = 1.54

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

api_key = 'ea5a6a489f20e6f7d5dcff2633c62edd'
cities = ['Seoul','Tokyo','New%20York']
for city in cities:
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
    request = urllib.request.Request(url)
    response = urllib.request.urlopen(request)
    res_body = response.read().decode('utf-8')
    res_dict = json.loads(res_body)
    #print(res_dict2)
    print(f"도시 = {res_dict['name']} | 날씨 = {res_dict['weather'][0]['description']} | 최저 기온 = {round(float(res_dict['main']['temp_min'])-273.15,2)} | 최대 기온 = {round(float(res_dict['main']['temp_max'])-273.15,2)} | 습도 = {res_dict['main']['humidity']} | 기압 = {res_dict['main']['pressure']} | 풍속 = {res_dict['wind']['speed']}")
# Out:
# 도시 = Seoul | 날씨 = clear sky | 최저 기온 = -2.27 | 최대 기온 = 2.69 | 습도 = 67 | 기압 = 1022 | 풍속 = 3.09
# 도시 = Tokyo | 날씨 = snow | 최저 기온 = -0.27 | 최대 기온 = 2.79 | 습도 = 92 | 기압 = 1019 | 풍속 = 7.72
# 도시 = New York | 날씨 = light snow | 최저 기온 = -1.8 | 최대 기온 = 1.08 | 습도 = 90 | 기압 = 1022 | 풍속 = 5.14

# %%
# 유용한 open api를 탐색해서 이용 방법과 실제 사용 사례를 소개
